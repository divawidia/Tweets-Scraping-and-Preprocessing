# %%
import pandas as pd
import os

# %%
# buat variabel untuk di format cli snscrape
jumlah_tweet = 1000
query = "ppkm"
tanggal_mulai = "2021-07-03"
tanggal_akhir = "2021-07-20"

# memakai library OS untuk menggunakan command cli di python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> data-tweets.json'.format(jumlah_tweet, tanggal_mulai, query, tanggal_akhir))
# Out:
# 0

# %%
# membaca file json yang dibuat dengan pandas dataframe
tweets_df2 = pd.read_json('data-tweets.json', lines=True)

# menampilkan 5 data pertama
tweets_df2.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/hogwarxt/status/1417273030...
# 1  https://twitter.com/O957VK/status/141727302765...
# 2  https://twitter.com/izoomw/status/141727302695...
# 3  https://twitter.com/abracadabrellaa/status/141...
# 4  https://twitter.com/O957VK/status/141727300202...
#
#                        date  \
# 0 2021-07-19 23:59:56+00:00
# 1 2021-07-19 23:59:56+00:00
# 2 2021-07-19 23:59:55+00:00
# 3 2021-07-19 23:59:50+00:00
# 4 2021-07-19 23:59:49+00:00
#
#                                              content  \
# 0                               @SCWWIINN7 ppkm fren
# 1                         @lchimolalla pasti ppkm :(
# 2  @Itzgyulicious iya sih pasti di batas juga yan...
# ...

# %%
from pymongo import MongoClient
import pymongo
import numpy as np

# %%
koneksi_mongodb = "mongodb+srv://user:pass123@analisissentimenppkm.aupcv.mongodb.net/myFirstDatabase?retryWrites=true&w=majority"

# %%
cluster = MongoClient(koneksi_mongodb)
db = cluster['tweetPPKM'] # use or create a database named demo
collection = db['tweetsKotor'] #use or create a collection named tweet_collection

# %%
data = collection.find()

dataFrame = pd.DataFrame(list(data))

dataFrame.head()
# Out:
#                         _id                           _type  \
# 0  6193e9f0c711981afbd29539  snscrape.modules.twitter.Tweet
# 1  6193e9f0c711981afbd2953a  snscrape.modules.twitter.Tweet
# 2  6193e9f0c711981afbd2953b  snscrape.modules.twitter.Tweet
# 3  6193e9f0c711981afbd2953c  snscrape.modules.twitter.Tweet
# 4  6193e9f0c711981afbd2953d  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/hogwarxt/status/1417273030...
# 1  https://twitter.com/O957VK/status/141727302765...
# 2  https://twitter.com/izoomw/status/141727302695...
# 3  https://twitter.com/abracadabrellaa/status/141...
# 4  https://twitter.com/O957VK/status/141727300202...
#
#                         date  \
# 0  2021-07-19T23:59:56+00:00
# 1  2021-07-19T23:59:56+00:00
# 2  2021-07-19T23:59:55+00:00
# 3  2021-07-19T23:59:50+00:00
# 4  2021-07-19T23:59:49+00:00
#
#                                              content  \
# ...

# %%
data_text = collection.find({}, {"_id": 0, "content": 1})

df_text = pd.DataFrame(list(data_text))

df_text
# Out:
#                                                content
# 0                                 @SCWWIINN7 ppkm fren
# 1                           @lchimolalla pasti ppkm :(
# 2    @Itzgyulicious iya sih pasti di batas juga yan...
# 3            PPKM = Pandai Pandai Kaulah cari Mesjid 🤧
# 4                                 @ksjincha ppkm ya :(
# ..                                                 ...
# 995  Ini Usulan Ganjar Jika PPKM Darurat Diperpanja...
# 996               PPKM ;\nPemuda Pemudi Kembali Mletre
# 997  PPKM Darurat Diperpanjang, PKB Minta Pemerinta...
# 998  Hari Ketujuh, Polsek Percut Sei Tuan dan Kecam...
# 999  Kodim 1207/Pontianak Saat Pelaksanaan TMMD Ke-...
#
# [1000 rows x 1 columns]
